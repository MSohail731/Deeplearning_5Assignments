# %% [markdown]
# <a href="https://colab.research.google.com/github/MSohail731/Deeplearning_5Assignments/blob/main/Ionosphere_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment: Ionosphere Data Problem
#
# ### Dataset Description:
#
# This radar data was collected by a system in Goose Bay, Labrador. This system consists of a phased array of 16 high-frequency antennas with a total transmitted power on the order of 6.4 kilowatts. See the paper for more details. The targets were free electrons in the ionosphere. "Good" radar returns are those showing evidence of some type of structure in the ionosphere. "Bad" returns are those that do not; their signals pass through the ionosphere.
#
# Received signals were processed using an autocorrelation function whose arguments are the time of a pulse and the pulse number. There were 17 pulse numbers for the Goose Bay system. Instances in this databse are described by 2 attributes per pulse number, corresponding to the complex values returned by the function resulting from the complex electromagnetic signal.
#
# ### Attribute Information:
#
# - All 34 are continuous
# - The 35th attribute is either "good" or "bad" according to the definition summarized above. This is a binary classification task.
#
#  <br><br>
#
# <table border="1"  cellpadding="6">
# 	<tbody>
#         <tr>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Data Set Characteristics:&nbsp;&nbsp;</b></p></td>
# 		<td><p class="normal">Multivariate</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Number of Instances:</b></p></td>
# 		<td><p class="normal">351</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Area:</b></p></td>
# 		<td><p class="normal">Physical</p></td>
#         </tr>
#      </tbody>
#     </table>
# <table border="1" cellpadding="6">
#     <tbody>
#         <tr>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Attribute Characteristics:</b></p></td>
#             <td><p class="normal">Integer,Real</p></td>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Number of Attributes:</b></p></td>
#             <td><p class="normal">34</p></td>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Date Donated</b></p></td>
#             <td><p class="normal">N/A</p></td>
#         </tr>
#      </tbody>
#     </table>
# <table border="1" cellpadding="6">
#     <tbody>
#     <tr>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Associated Tasks:</b></p></td>
# 		<td><p class="normal">Classification</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Missing Values?</b></p></td>
# 		<td><p class="normal">N/A</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Number of Web Hits:</b></p></td>
# 		<td><p class="normal">N/A</p></td>
# 	</tr>
#     </tbody>
#     </table>

# %% [markdown]
# ### WORKFLOW :
# - Load Data
# - Check Missing Values ( If Exist ; Fill each record with mean of its feature ) or any usless column.
# - Shuffle the data if needed.
# - Standardized the Input Variables. **Hint**: Centeralized the data
# - Split into 60 and 40 ratio.
# - Encode labels.
# - Model : 1 hidden layers including 16 unit.
# - Compilation Step (Note : Its a Binary problem , select loss , metrics according to it)
# - Train the Model with Epochs (100).
# - If the model gets overfit tune your model by changing the units , No. of layers , epochs , add dropout layer or add Regularizer according to the need .
# - Prediction should be > **92%**
# - Evaluation Step
# - Prediction

# %% [markdown]
# # Load Data:
# [Click Here to Download DataSet](https://github.com/ramsha275/ML_Datasets/blob/main/ionosphere_data.csv)

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_csv("/content/gdrive/MyDrive/CSV_Files/ionosphere_data.csv")
df.head()
# Out:
#    feature1  feature2  feature3  ...  feature33  feature34  label
# 0         1         0   0.99539  ...    0.18641   -0.45300      g
# 1         1         0   1.00000  ...   -0.13738   -0.02447      b
# 2         1         0   1.00000  ...    0.56045   -0.38238      g
# 3         1         0   1.00000  ...   -0.32382    1.00000      b
# 4         1         0   1.00000  ...   -0.04608   -0.65697      g
#
# [5 rows x 35 columns]

# %%
df1 =df['label']
df1.value_counts()
# Out:
# g    225
# b    126
# Name: label, dtype: int64

# %%
df.sample(3)
# Out:
#      feature1  feature2  feature3  ...  feature33  feature34  label
# 196         1         0   1.00000  ...        1.0        1.0      b
# 79          0         0   1.00000  ...       -1.0        1.0      b
# 59          1         0   0.17188  ...        0.0        0.0      b
#
# [3 rows x 35 columns]

# %%
df.drop_duplicates()
# Out:
#      feature1  feature2  feature3  ...  feature33  feature34  label
# 0           1         0   0.99539  ...    0.18641   -0.45300      g
# 1           1         0   1.00000  ...   -0.13738   -0.02447      b
# 2           1         0   1.00000  ...    0.56045   -0.38238      g
# 3           1         0   1.00000  ...   -0.32382    1.00000      b
# 4           1         0   1.00000  ...   -0.04608   -0.65697      g
# ..        ...       ...       ...  ...        ...        ...    ...
# 346         1         0   0.83508  ...    0.90546   -0.04307      g
# 347         1         0   0.95113  ...    0.91483    0.04712      g
# 348         1         0   0.94701  ...    0.92697   -0.00577      g
# 349         1         0   0.90608  ...    0.87403   -0.16243      g
# 350         1         0   0.84710  ...    0.85764   -0.06151      g
#
# [350 rows x 35 columns]

# %%
df.describe()
# Out:
#          feature1  feature2    feature3  ...   feature32   feature33   feature34
# count  351.000000     351.0  351.000000  ...  351.000000  351.000000  351.000000
# mean     0.891738       0.0    0.641342  ...   -0.003794    0.349364    0.014480
# std      0.311155       0.0    0.497708  ...    0.513574    0.522663    0.468337
# min      0.000000       0.0   -1.000000  ...   -1.000000   -1.000000   -1.000000
# 25%      1.000000       0.0    0.472135  ...   -0.242595    0.000000   -0.165350
# 50%      1.000000       0.0    0.871110  ...    0.000000    0.409560    0.000000
# 75%      1.000000       0.0    1.000000  ...    0.200120    0.813765    0.171660
# max      1.000000       0.0    1.000000  ...    1.000000    1.000000    1.000000
#
# [8 rows x 34 columns]

# %%
data=df.iloc[:,:-1]
label=df.iloc[:,-1]

# %%
label = df["label"].map({'g':1,'b':0})

# %%
X_train=data.sample(frac=0.6,random_state=1)
X_test=data.sample(frac=0.4,random_state=1)
y_train=label.sample(frac=0.6,random_state=1)
y_test=label.sample(frac=0.4,random_state=1)

# %%
X_train=np.asarray(X_train).astype("float32")
X_test=np.asarray(X_test).astype("float32")

# %%
from keras import models, layers , optimizers ,regularizers,losses
network=models.Sequential()
network.add(layers.Dense(16,activation="relu",input_shape=(X_train.shape[1],)))
#network.add(layers.Dense(8,kernel_regularizer=regularizers.l2(0.0001),activation="relu"))
network.add(layers.Dense(1,activation="sigmoid"))
network.compile(optimizer="rmsprop",loss="binary_crossentropy",metrics=["accuracy"])

# %%
network.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                560
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 577
# Trainable params: 577
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = network.fit(X_train,y_train,epochs=50,batch_size=1,verbose=1)
# Out:
# Epoch 1/50
# 211/211 [==============================] - 1s 1ms/step - loss: 0.6490 - accuracy: 0.6969
# Epoch 2/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.5711 - accuracy: 0.7381
# Epoch 3/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.4598 - accuracy: 0.7632
# Epoch 4/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.4328 - accuracy: 0.8227
# Epoch 5/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.3703 - accuracy: 0.8702
# Epoch 6/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.2873 - accuracy: 0.9159
# Epoch 7/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.3105 - accuracy: 0.8822
# Epoch 8/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.3140 - accuracy: 0.8674
# Epoch 9/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.2756 - accuracy: 0.8724
# Epoch 10/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.3044 - accuracy: 0.8662
# Epoch 11/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.2294 - accuracy: 0.9028
# Epoch 12/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.2458 - accuracy: 0.8949
# Epoch 13/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1606 - accuracy: 0.9451
# Epoch 14/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1616 - accuracy: 0.9454
# Epoch 15/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1857 - accuracy: 0.9298
# Epoch 16/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1643 - accuracy: 0.9444
# Epoch 17/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1475 - accuracy: 0.9402
# Epoch 18/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1755 - accuracy: 0.9325
# Epoch 19/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1128 - accuracy: 0.9693
# Epoch 20/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1935 - accuracy: 0.9335
# Epoch 21/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1172 - accuracy: 0.9535
# Epoch 22/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1288 - accuracy: 0.9506
# Epoch 23/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1069 - accuracy: 0.9653
# Epoch 24/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1159 - accuracy: 0.9589
# Epoch 25/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1548 - accuracy: 0.9418
# Epoch 26/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1320 - accuracy: 0.9266
# Epoch 27/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1390 - accuracy: 0.9323
# Epoch 28/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1006 - accuracy: 0.9708
# Epoch 29/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0907 - accuracy: 0.9618
# Epoch 30/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0859 - accuracy: 0.9779
# Epoch 31/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0919 - accuracy: 0.9698
# Epoch 32/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0816 - accuracy: 0.9639
# Epoch 33/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1122 - accuracy: 0.9676
# Epoch 34/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0706 - accuracy: 0.9737
# Epoch 35/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0952 - accuracy: 0.9737
# Epoch 36/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0716 - accuracy: 0.9812
# Epoch 37/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0909 - accuracy: 0.9779
# Epoch 38/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0903 - accuracy: 0.9725
# Epoch 39/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0461 - accuracy: 0.9925
# Epoch 40/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1225 - accuracy: 0.9487
# Epoch 41/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0810 - accuracy: 0.9702
# Epoch 42/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0443 - accuracy: 0.9877
# Epoch 43/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0636 - accuracy: 0.9833
# Epoch 44/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1741 - accuracy: 0.9443
# Epoch 45/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0633 - accuracy: 0.9855
# Epoch 46/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0797 - accuracy: 0.9717
# Epoch 47/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0634 - accuracy: 0.9833
# Epoch 48/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1501 - accuracy: 0.9595
# Epoch 49/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0646 - accuracy: 0.9812
# Epoch 50/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0858 - accuracy: 0.9736

# %%
history_dict = history.history
history_dict.keys()
[u'accuracy', u'loss']
# Out:
# ['accuracy', 'loss']

# %%
loss_acc=pd.DataFrame(history.history)
loss_acc.tail().T
# Out:
#                 45        46        47        48        49
# loss      0.094715  0.087885  0.091384  0.095047  0.096135
# accuracy  0.971564  0.971564  0.971564  0.971564  0.966825

# %%
import matplotlib.pyplot as plt
history_dict = history.history
loss_values = history_dict['loss']
accuracy_values = history_dict['accuracy']
epochs = range(1, len(history_dict['accuracy']) + 1)
plt.plot(epochs, loss_values, 'g', label='loss')
plt.plot(epochs, accuracy_values, 'b', label='accuracy')
plt.title('Accuracy & Loss ')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# %%
network.evaluate(X_test,y_test)
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0599 - accuracy: 0.9786
# [0.059923239052295685, 0.9785714149475098]

# %%
pred=network.predict(X_test)
pred.flatten().astype("U8")
# Out:
# array(['0.007862', '0.999289', '0.002162', '0.999559', '0.907119',
#        '0.999427', '0.998595', '0.949071', '0.000351', '0.069952',
#        '0.996267', '0.999332', '0.006052', '0.994945', '0.000205',
#        '0.006915', '0.634714', '0.003221', '0.986075', '0.000126',
#        '0.542039', '0.970154', '0.997453', '0.937706', '3.07569e',
#        '0.999657', '0.986321', '0.998350', '0.860146', '0.998468',
#        '0.001135', '0.999094', '0.000324', '0.032484', '0.998516',
#        '0.999566', '0.042577', '1.243516', '0.998959', '0.999806',
#        '0.976542', '0.996715', '0.994133', '0.997125', '0.999525',
#        '0.958799', '0.998196', '0.995859', '0.107950', '0.997787',
#        '0.942615', '0.999841', '0.055427', '0.004376', '0.999927',
#        '0.992146', '0.002707', '1.299860', '0.000362', '0.998291',
#        '0.997717', '0.007028', '0.999294', '0.012489', '0.000516',
#        '0.999078', '4.569125', '0.999737', '0.997314', '1.902935',
#        '0.997762', '0.018768', '0.003436', '0.998607', '0.013082',
#        '0.001303', '0.999295', '0.997163', '0.997708', '0.973499',
#        '0.963476', '0.999898', '0.992011', '0.999879', '0.999405',
#        '0.999789', '0.995207', '0.995341', '0.962991', '0.995412',
#        '0.975242', '0.000200', '0.000784', '0.975515', '0.997844',
#        '0.001649', '0.995710', '0.996827', '0.992327', '0.997666',
#        '0.997906', '0.000144', '0.983652', '0.998841', '0.998460',
#        '0.670215', '3.998010', '0.997381', '0.999782', '0.998898',
#        '0.999862', '0.998103', '0.792295', '0.997202', '0.999752',
#        '0.985703', '0.000171', '0.997350', '1.031398', '0.986258',
#        '0.999042', '0.911711', '3.207039', '0.978346', '0.991197',
#        '0.013368', '0.981277', '0.002115', '0.999544', '0.999179',
#        '0.998434', '0.999814', '0.802301', '0.019476', '0.998574',
#        '0.001650', '0.994727', '3.501845', '0.998762', '0.000176'],
#       dtype='<U8')
